# %%
import random 
import time


rock = 1
paper = 2
scissors = 3

names = {rock:"Rock" , paper:"Paper" , scissors  : "Scissors"}

rules = {rock:scissors  , paper : rock ,scissors:paper}

player_score = 0
computer_score = 0


def start():
    print("Lets's play  a game  of Rock  , Paper , Scissors:")
    while game():
        pass
    scores()
    
def game():
    player = move()
    computer = random.randint(1,3)
    result(player , computer)
    return play_again()

def move():
    while True:
        
        player = int(input("Rock = 1\n Paper = 2 \n Scissors = 3\n Make a Move"))
        try:
            player = int(player)
            if player in (1,2,3):
                return player
        except ValueError:
            pass
        print("OOps !! I Didn't understand that Please Enter 1  ,2 and 3 ")
        
        
def  result(player , computer):
    print("*1.....*")
    time.sleep(1)
    print("*2....*")
    time.sleep(1)
    print("*3....*")
    time.sleep(0.5)
    print("Computer threw {0}!".format(names[computer]))
    global player_score , computer_score
    if player == computer:
        print("Tie Game")
    else:
        if rules[player]==computer:
            print("You victory has been Assured.")
            player_score +=1
        else:
            print("The Computer laughs as you realise you have been defeated")
            computer_score+=1

            
def play_again():
    answer = input("Would you like to play again y/n:")
    if answer in ("y" , "Y" , "yes" ,"Yes" ,"Of Course:"):
        return answer
    else:
        print("Thank you very much for playing the game , See you next time")
        


def scores():
    global player_score , computer_score
    print("High Scores")
    print("Player:" , player_score)
    print("Computer :" , computer_score)
    
    

if __name__ == '__main__':
    start()
# Out:
# Lets's play  a game  of Rock  , Paper , Scissors:
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move1
# *1.....*
# *2....*
# *3....*
# Computer threwRock!
# Tie Game
# Would you like to play again y/n:y
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move5
# OOps !! I Didn't understand that Please Enter 1  ,2 and 3
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move2
# *1.....*
# *2....*
# *3....*
# Computer threwRock!
# You victory has been Assured.
# Would you like to play again y/n:y
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move3
# *1.....*
# *2....*
# *3....*
# Computer threwScissors!
# Tie Game
# Would you like to play again y/n:y
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move1
# *1.....*
# *2....*
# *3....*
# Computer threwRock!
# Tie Game
# Would you like to play again y/n:y
# Rock = 1
#  Paper = 2
#  Scissors = 3
#  Make a Move3
# *1.....*
# *2....*
# *3....*
# Computer threwRock!
# The Computer laughs as you realise you have been defeated
# ...
